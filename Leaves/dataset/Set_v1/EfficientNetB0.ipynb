# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0

# Load the EfficientNetB0 model
model = EfficientNetB0(weights='imagenet', include_top=True)

# Print the model summary
model.summary()
# Out:
# ...
# 21834768/21834768 [==============================] - 3s 0us/step
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 224, 224, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
# ...

# %%
def build_efficientnet_b0(input_shape=(112, 112, 16), num_classes=3):
    # Initialize the model
    model = tf.keras.Sequential([
        # Stem
        Conv2D(32, (3, 3), strides=(2, 2), padding='same', input_shape=input_shape),
        BatchNormalization(),
        Activation('swish'),
    ])
    
    # Blocks
    model = _build_efficientnet_block(model, 16, 1, 1)
    model = _build_efficientnet_block(model, 24, 2, 6)
    model = _build_efficientnet_block(model, 40, 2, 6)
    model = _build_efficientnet_block(model, 80, 3, 6)
    model = _build_efficientnet_block(model, 112, 3, 6)
    model = _build_efficientnet_block(model, 192, 4, 6)
    model = _build_efficientnet_block(model, 320, 1, 6)
    
    # Head
    model.add(Conv2D(1280, (1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('swish'))
    model.add(GlobalAveragePooling2D())
    
    # Fully connected layers
    model.add(Dense(1280, activation='swish'))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\SAnuv\Documents\Computer Engineering\Research Project\Coco_Anuvathan\Leaves\dataset\Set_v1\EfficientNetB0.ipynb Cell 2 line <cell line: 56>()
#      <a href='vscode-notebook-cell:/c%3A/Users/SAnuv/Documents/Computer%20Engineering/Research%20Project/Coco_Anuvathan/Leaves/dataset/Set_v1/EfficientNetB0.ipynb#W1sZmlsZQ%3D%3D?line=52'>53</a>     return model
#      <a href='vscode-notebook-cell:/c%3A/Users/SAnuv/Documents/Computer%20Engineering/Research%20Project/Coco_Anuvathan/Leaves/dataset/Set_v1/EfficientNetB0.ipynb#W1sZmlsZQ%3D%3D?line=54'>55</a> # Create the model
# ---> <a href='vscode-notebook-cell:/c%3A/Users/SAnuv/Documents/Computer%20Engineering/Research%20Project/Coco_Anuvathan/Leaves/dataset/Set_v1/EfficientNetB0.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a> model = build_efficientnet_b0()
# ...
