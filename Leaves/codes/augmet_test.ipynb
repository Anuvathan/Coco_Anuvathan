# %%
from PIL import Image, ImageEnhance
import os

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/test/healthy"

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # Rotate the image 90 degrees clockwise and save it
#         # rotated_image_90 = image.rotate(90)
#         # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # Rotate the image 90 degrees counterclockwise and save it
#         # rotated_image_minus_90 = image.rotate(-90)
#         # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # Horizontal flip the image and save it
#         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/test/caterpillar"

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)


#         # # Rotate the image 90 degrees clockwise and save it
#         # rotated_image_90 = image.rotate(90)
#         # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # Rotate the image 90 degrees counterclockwise and save it
#         # rotated_image_minus_90 = image.rotate(-90)
#         # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # Horizontal flip the image and save it
#         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/test/leafspot"

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # Rotate the image 90 degrees clockwise and save it
#         # rotated_image_90 = image.rotate(90)
#         # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # Rotate the image 90 degrees counterclockwise and save it
#         # rotated_image_minus_90 = image.rotate(-90)
#         # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # Horizontal flip the image and save it
#         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/train/healthy"

# # Function to apply brightness and contrast adjustments to an image
# def adjust_brightness_contrast(image, brightness_factor, contrast_factor):
#     enhancer = ImageEnhance.Brightness(image)
#     image = enhancer.enhance(brightness_factor)

#     enhancer = ImageEnhance.Contrast(image)
#     image = enhancer.enhance(contrast_factor)

#     return image

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # # Rotate the image 90 degrees clockwise and save it
#         # # rotated_image_90 = image.rotate(90)
#         # # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # # Rotate the image 90 degrees counterclockwise and save it
#         # # rotated_image_minus_90 = image.rotate(-90)
#         # # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # # Horizontal flip the image and save it
#         # flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         # flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         # Adjust brightness and contrast in different combinations
#         adjustments = [
#             {"brightness": 1.3, "contrast": 1.3},  # Brightness increase, Contrast increase
#             {"brightness": 0.7, "contrast": 0.7},  # Brightness decrease, Contrast decrease
#             {"brightness": 1.3, "contrast": 0.7},  # Brightness increase, Contrast decrease
#             {"brightness": 0.7, "contrast": 1.3},  # Brightness decrease, Contrast increase
#         ]

#         for i, adj in enumerate(adjustments):
#             adjusted_image = adjust_brightness_contrast(image.copy(), adj["brightness"], adj["contrast"])
#             adjusted_image.save(os.path.join(folder_path, f"adjusted_{i}_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/train/caterpillar"

# # Function to apply brightness and contrast adjustments to an image
# def adjust_brightness_contrast(image, brightness_factor, contrast_factor):
#     enhancer = ImageEnhance.Brightness(image)
#     image = enhancer.enhance(brightness_factor)

#     enhancer = ImageEnhance.Contrast(image)
#     image = enhancer.enhance(contrast_factor)

#     return image

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # # Rotate the image 90 degrees clockwise and save it
#         # # rotated_image_90 = image.rotate(90)
#         # # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # # Rotate the image 90 degrees counterclockwise and save it
#         # # rotated_image_minus_90 = image.rotate(-90)
#         # # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # # Horizontal flip the image and save it
#         # flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         # flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         # Adjust brightness and contrast in different combinations
#         adjustments = [
#             {"brightness": 1.3, "contrast": 1.3},  # Brightness increase, Contrast increase
#             {"brightness": 0.7, "contrast": 0.7},  # Brightness decrease, Contrast decrease
#             {"brightness": 1.3, "contrast": 0.7},  # Brightness increase, Contrast decrease
#             {"brightness": 0.7, "contrast": 1.3},  # Brightness decrease, Contrast increase
#         ]

#         for i, adj in enumerate(adjustments):
#             adjusted_image = adjust_brightness_contrast(image.copy(), adj["brightness"], adj["contrast"])
#             adjusted_image.save(os.path.join(folder_path, f"adjusted_{i}_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/train/leafspot"

# # Function to apply brightness and contrast adjustments to an image
# def adjust_brightness_contrast(image, brightness_factor, contrast_factor):
#     enhancer = ImageEnhance.Brightness(image)
#     image = enhancer.enhance(brightness_factor)

#     enhancer = ImageEnhance.Contrast(image)
#     image = enhancer.enhance(contrast_factor)

#     return image

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # # Rotate the image 90 degrees clockwise and save it
#         # # rotated_image_90 = image.rotate(90)
#         # # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # # Rotate the image 90 degrees counterclockwise and save it
#         # # rotated_image_minus_90 = image.rotate(-90)
#         # # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # # Horizontal flip the image and save it
#         # flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         # flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         # Adjust brightness and contrast in different combinations
#         adjustments = [
#             {"brightness": 1.3, "contrast": 1.3},  # Brightness increase, Contrast increase
#             {"brightness": 0.7, "contrast": 0.7},  # Brightness decrease, Contrast decrease
#             {"brightness": 1.3, "contrast": 0.7},  # Brightness increase, Contrast decrease
#             {"brightness": 0.7, "contrast": 1.3},  # Brightness decrease, Contrast increase
#         ]

#         for i, adj in enumerate(adjustments):
#             adjusted_image = adjust_brightness_contrast(image.copy(), adj["brightness"], adj["contrast"])
#             adjusted_image.save(os.path.join(folder_path, f"adjusted_{i}_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/val/healthy"

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # Rotate the image 90 degrees clockwise and save it
#         # rotated_image_90 = image.rotate(90)
#         # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # Rotate the image 90 degrees counterclockwise and save it
#         # rotated_image_minus_90 = image.rotate(-90)
#         # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # Horizontal flip the image and save it
#         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/val/caterpillar"

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # Rotate the image 90 degrees clockwise and save it
#         # rotated_image_90 = image.rotate(90)
#         # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # Rotate the image 90 degrees counterclockwise and save it
#         # rotated_image_minus_90 = image.rotate(-90)
#         # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # Horizontal flip the image and save it
#         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")

# %%
# # Define the folder path
# folder_path = "../dataset_resized_224x224/split/fold5/val/leafspot"

# # Loop through all the files in the folder
# for filename in os.listdir(folder_path):
#     if filename.endswith(".JPG"):  # You can specify the image file extensions you're working with
#         file_path = os.path.join(folder_path, filename)

#         # Load the image
#         image = Image.open(file_path)

#         # # Rotate the image 90 degrees clockwise and save it
#         # rotated_image_90 = image.rotate(90)
#         # rotated_image_90.save(os.path.join(folder_path, f"rotated_90_{filename}"))

#         # # Rotate the image 90 degrees counterclockwise and save it
#         # rotated_image_minus_90 = image.rotate(-90)
#         # rotated_image_minus_90.save(os.path.join(folder_path, f"rotated_minus_90_{filename}"))

#         # Horizontal flip the image and save it
#         flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
#         flipped_image.save(os.path.join(folder_path, f"flipped_{filename}"))

#         print(f"Processed: {filename}")

# print("Rotation and saving completed.")
